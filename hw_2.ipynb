# %% [markdown]
# # CS82 - Introduction to Machine Learning
#
# ## Homework 2
#
#
# ### Submission
#
# email a completed copy of this notebook to danny@ktbyte.com with subject:
# `[CS82] HW2 - Student Name`
#
# ## Description
#
# To complete this homework you will need to read:
# * [Handout 2](https://content.ktbyte.com/cs82/20sp/handout/1.html)
# * [Workshop 2](https://content.ktbyte.com/cs82/20sp/workshop/1.html)
# * [Handout 3](https://content.ktbyte.com/cs82/20sp/handout/2.html)
#
# **Tasks** are to be performed and their output saved
# **Questions** are to be answered and their output saved

# %% [markdown]
# ### TASK
# * Register a new account at [Kaggle.com](http://kaggle.com)
# * Find a Dataset to work with from Kaggle.
# * Add the link to the dataset as a comment.
# * Download the dataset and import it as a local file into a dataframe
# * Display the head of the dataframe
#
# **Tip**: Use pandas

# %%
import pandas as pd
df = pd.read_csv("GlobalLandTemperaturesByCountry.csv")
# link: https://www.kaggle.com/berkeleyearth/climate-change-earth-surface-temperature-data/download

# %% [markdown]
# ### Question
#
# * Describe your dataset.
# * What are the attributes of your dataset?
# * What data type each attribute is?
# * What problem could we solve using this dataset?
# * What are you dependent and indepedent variables?

# %% [markdown]
# Answer: This dataset represents the average temperatures in different countries on Earth over a range of time.
# The attributes of this dataset are the average temperature, the time the measurements were recorded, the country, latitude, longititude, and average temperature uncertainty.
# The countries, latitudes, longitudes, and dates are in the form of a string.
# Average Temperatures and Average Temperature Uncertainties are in the form of floats.
# This dataset could aid in research regarding the effects of global warming and climate change on a country by country basis to determine how each country is facing against climate change.
# The independent variable could be the time (date).
# The dependent variable is going to be the average temperature in celsius.

# %% [markdown]
# ### TASK
# * Visualize each indepedent variable with the dependent variable you are trying to predict
#
# **Tip**: Use matplotlib

# %%
import matplotlib.pyplot as plt
df.dropna(inplace = True)
plt.scatter(df[df['Country'] == 'United States']['dt'], df[df['Country'] == 'United States']['AverageTemperature'])
plt.show()

# %% [markdown]
# ### Question
#
# * Which independent variables show a strong relationship with the depedent variable?

# %% [markdown]
# Answer: Time shows a much stronger relationship with the dependent variable of average temperature.

# %% [markdown]
# ### TASK
# * Use a build-in pandas function to *describe* the statistical breakdown of your dataframe's values.
# * Use conditional statements to obtain a range of values from your indepedent variable and the corresponding depedent variable.
# * Plot the conditioned dependent and indepedent variable

# %%
df.describe()
# df[df['Country'] == 'United States']['AverageTemperature']
df[df['Country'] == 'United States'][(df['AverageTemperature'] > 15)]
df['dt'][:][:][5][6] == '0' # 5 = string, 6 = index
# df[df['Country'] == 'United States'][df['dt'][6] == '0']
# df[df['Country'] == 'United States'][df['dt'][:][:][5][6]  == '0'] doesn't work :(
# Goal: try to get only items with dates in January and nothing more
df['dt']['AverageTemperature'] # I think this doesn't work because there are multiple data points at each date
# I got too much data so I didn't have enough time to process all of it correctly :/
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-0a7100c03f3a> in <module>
#       6 # df[df['Country'] == 'United States'][df['dt'][:][:][5][6]  == '0'] doesn't work :(
#       7 # Goal: try to get only items with dates in January and nothing more
# ----> 8 df['dt']['AverageTemperature']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1062         key = com.apply_if_callable(key, self)
#    1063         try:
# -> 1064             result = self.index.get_value(self, key)
#    1065
#    1066             if not is_scalar(result):
#
# ...

# %% [markdown]
# ### Question
# * Why is Linear Algebra important for Machine Learning?
# * What is a vector?
# * What is a matrix?
# * What is a conditional probability?
# * What is local minima?
#
# **Tip** you might have to read Handout 3

# %% [markdown]
# Linear Algebra is important for Machine Learning because it allows you to act upon a large set of data using single operations which makes abstracting that data and understanding it much easier.
# Vectors are arrays of elements.
# Matrices are 2-d vectors.
# Conditional Probability is a way of describing how likely something is to happen either based on another event or condition.
# The smallest value of a function within a given area.
